# %% [markdown]
# # Minha Primeira Plotagem com Python:
# - Linear:

# %%
import matplotlib.pyplot as plt

#listas dos dados
x = [1,2,5]
y = [2,4,10]

#titúlo do gráfico
plt.title("Primeiro gráfico com Python")

#legenda dos eixos
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")

plt.plot(x,y) #plotar
plt.show() #visualizar

# %% [markdown]
# - Barras:

# %%
import matplotlib.pyplot as plt

#listas de dados
x1 = [1,3,5,7,9]
y1 = [2,4,6,8,10]

x2 = [2,4,6,8,10]
y2 = [5,1,3,7,4]

titulo = "Gráfico de barras 2"
eixox = "Eixo X"
eixoy = "Eixo Y"

#título
plt.title(titulo)

#eixos
plt.xlabel(eixox)
plt.ylabel(eixoy)

#separação das barras
plt.bar(x1,y1, label = "Grupo 1")
plt.bar(x2,y2, label = "Grupo 2")

plt.legend() #cria legenda
plt.show() #visualiza

# %% [markdown]
# - Dispersão:

# %%
import matplotlib.pyplot as plt

#lista de dados
x = [1,3,5,7,9]
y = [2,3,7,1,0]
z = [200,45,400,330,100] #definir tamanho dos pontos

titulo = "Scatterplot: Gráfico de dispersão"
eixox = "Eixo X"
eixoy = "Eixo Y"

plt.title(titulo)

#eixos
plt.xlabel(eixox)
plt.ylabel(eixoy)

plt.plot(x,y, label="Minha Linha", color ="#990000", linestyle=':')

#marcadores com cores e tamanhos
plt.scatter(x,y, label="Meus Pontos", color= "g", marker=".", s=z)
plt.legend() #legendas

plt.savefig("figura1.png") #salvar em png

#pode configurar a resolução do pdf
plt.savefig("figura1.pdf", dpi=600) #salvar em pdf
